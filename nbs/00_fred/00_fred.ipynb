# %% [markdown]
# # fred
#
# > Retrieve and process data from the St. Louis FRED

# %% [markdown]
# This module is a wrapper on the `fred_api` module, which itself is a fork of [fredapi](https://github.com/mortada/fredapi).

# %% [markdown]
# To use the functions in the `fred` module, you'll need an API key from the St. Louis FRED.
#
# Get one [here](https://fred.stlouisfed.org/docs/api/api_key.html) and store it in your environment variables under the name `FRED_API_KEY`
#
# Alternatively, you can supply the API key directly as the `api_key` parameter in each function in the `fred` module.

# %%
#| default_exp fred.fred

# %%
#| exports
from typing import List, Dict
import os, time

import pandas as pd

import pandasmore as pdm
from finsets.fred.fred_api import Fred
from finsets import RESOURCES

# %%
#| exports
PROVIDER = 'Federal Reserve Economic Data (FRED)'
URL = 'https://fred.stlouisfed.org/'
LABELS_FILE = RESOURCES/'fred_variable_descriptions.csv'

# %%
#| export 
def get_series_info(series: str=None, # FRED series name
                    api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
                    ) -> pd.Series:
    """Get metadata from FRED for given `series` from FRED"""
    
    return Fred(api_key=api_key).get_series_info(series)

# %%
get_series_info('TB3MS')
# Out:
# id                                                                       TB3MS
# realtime_start                                                      2023-11-01
# realtime_end                                                        2023-11-01
# title                        3-Month Treasury Bill Secondary Market Rate, D...
# observation_start                                                   1934-01-01
# observation_end                                                     2023-10-01
# frequency                                                              Monthly
# frequency_short                                                              M
# units                                                                  Percent
# units_short                                                                  %
# seasonal_adjustment                                    Not Seasonally Adjusted
# seasonal_adjustment_short                                                  NSA
# last_updated                                            2023-11-01 15:21:08-05
# popularity                                                                  77
# notes                                Averages of Business Days, Discount Basis
# dtype: object

# %%
#| export
def default_raw_vars() -> pd.DataFrame:
    """List of FRED series that will be used in `download()` if none are specified"""

    return ['TB3MS','DTB3','GS10','DGS10','GS1','DGS1','AAA','BAA','DAAA','DBAA','FEDFUNDS','DFF','CPIAUCSL','CPIAUCNS','INDPRO','IPB50001SQ','UNRATE','GDP','GDPC1','GNP','GNPC96','GDPPOT','USREC','RECPROUSM156N','CFNAI','UMCSENT','MICH','USEPUINDXM','USEPUNEWSINDXM','USEPUINDXD','VIXCLS','VXOCLS']

# %%
print(default_raw_vars())
# Out:
# ['TB3MS', 'DTB3', 'GS10', 'DGS10', 'GS1', 'DGS1', 'AAA', 'BAA', 'DAAA', 'DBAA', 'FEDFUNDS', 'DFF', 'CPIAUCSL', 'CPIAUCNS', 'INDPRO', 'IPB50001SQ', 'UNRATE', 'GDP', 'GDPC1', 'GNP', 'GNPC96', 'GDPPOT', 'USREC', 'RECPROUSM156N', 'CFNAI', 'UMCSENT', 'MICH', 'USEPUINDXM', 'USEPUNEWSINDXM', 'USEPUINDXD', 'VIXCLS', 'VXOCLS']

# %%
#| export
def raw_metadata(vars: List[str]=None, #list of variables requested by user; if None, will use `default_raw_vars()`
                 api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
                 ) -> pd.DataFrame:
    
    if vars is None: vars = default_raw_vars()
    
    df = get_series_info(vars[0], api_key).to_frame().T
    for v in vars[1:]:
        time.sleep(0.1)
        df = pd.concat([df, get_series_info(v).to_frame().T])

    df['min_year'] = pd.to_datetime(df['observation_start']).dt.year 
    df['max_year'] = pd.to_datetime(df['observation_end']).dt.year 
    df = df.drop(['frequency','units', 'seasonal_adjustment'], axis=1)

    labels = pd.read_csv(LABELS_FILE)
    labels = labels.rename({'Variable Name': 'id', 'Description':'name'}, axis=1)

    meta = df.merge(labels, how='left', on='id')
    meta['output_of'] = 'fred.download'
    meta = pdm.order_columns(meta, these_first=['name','id','title','min_year','max_year','output_of'])
    
    meta = meta.rename({'id':'fred_id', 'title':'label', 'frequency_short':'frequency','units_short':'unity', 'seasonal_adjustment_short':'seasonal_adj'}, axis=1)

    return meta

# %%
#| eval: false
metadata = raw_metadata()

# %%
#| eval: false
metadata.head(2)
# Out:
#         name fred_id                                              label  \
# 0  yield_3mt   TB3MS  3-Month Treasury Bill Secondary Market Rate, D...
# 1  yield_3mt    DTB3  3-Month Treasury Bill Secondary Market Rate, D...
#
#    min_year  max_year      output_of realtime_start realtime_end  \
# 0      1934      2023  fred.download     2023-11-01   2023-11-01
# 1      1954      2023  fred.download     2023-11-01   2023-11-01
#
#   observation_start observation_end frequency unity seasonal_adj  \
# 0        1934-01-01      2023-10-01         M     %          NSA
# 1        1954-01-04      2023-10-31         D     %          NSA
#
#              last_updated popularity  \
# 0  2023-11-01 15:21:08-05         77
# 1  2023-11-01 15:20:09-05         75
#
#                                        notes
# 0  Averages of Business Days, Discount Basis
# 1                             Discount Basis

# %%
#| export
def parse_varlist(vars: List[str]=None, #list of variables requested by user; if None, will use `default_raw_vars()`
                  api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
                  ) -> Dict[str, list]:
    "Splits `vars` by frequency and returns dict with one pd.DataFrame per frequency"
     
    if vars is None: vars = default_raw_vars()

    df = pd.DataFrame(columns=['series','freq'])
    for series in vars:
        freq = get_series_info(series, api_key)['frequency_short']
        df = pd.concat([df,pd.DataFrame({'series': [series], 'freq': [freq]})], ignore_index=True)

    vars_by_freq = {}
    frequencies = list(df['freq'].value_counts().index)
    for f in frequencies:
        vars_with_this_freq = list(df['series'].loc[df.freq==f])
        vars_by_freq[f] = vars_with_this_freq

    return vars_by_freq

# %%
#| eval: false
varlist = parse_varlist()

# %%
#| eval: false
print(varlist['Q'])
# Out:
# ['IPB50001SQ', 'GDP', 'GDPC1', 'GNP', 'GNPC96', 'GDPPOT']

# %%
#| export 
def download(vars: str=None, # FRED series name
               api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
               ) -> Dict[str, pd.DataFrame]: 
    """Retrieves `vars` from FRED, splits them by frequency and returns dict with one pd.DataFrame per frequency"""

    api = Fred(api_key=api_key)

    varlist = parse_varlist(vars)

    out = {}
    for freq, vars in varlist.items():
        out[freq] = pd.concat([api.get_series(series).to_frame(name=series) for series in vars], axis=1).dropna(how='all')
        
    return out

# %%
#| eval: false
rdat = download()

# %%
#| eval: false
rdat.keys()
# Out:
# dict_keys(['M', 'D', 'Q'])

# %%
#| eval: false
rdat['Q']
# Out:
#             IPB50001SQ  GDP  GDPC1  GNP  GNPC96    GDPPOT
# 1919-01-01      4.6783  NaN    NaN  NaN     NaN       NaN
# 1919-04-01      4.7141  NaN    NaN  NaN     NaN       NaN
# 1919-07-01      5.2339  NaN    NaN  NaN     NaN       NaN
# 1919-10-01      5.1085  NaN    NaN  NaN     NaN       NaN
# 1920-01-01      5.5835  NaN    NaN  NaN     NaN       NaN
# ...                ...  ...    ...  ...     ...       ...
# 2024-10-01         NaN  NaN    NaN  NaN     NaN  21052.30
# 2025-01-01         NaN  NaN    NaN  NaN     NaN  21143.69
# 2025-04-01         NaN  NaN    NaN  NaN     NaN  21235.79
# 2025-07-01         NaN  NaN    NaN  NaN     NaN  21329.03
# 2025-10-01         NaN  NaN    NaN  NaN     NaN  21423.29
#
# [428 rows x 6 columns]

# %%
#| eval: false
rdat['M']
# Out:
#             TB3MS  GS10   GS1   AAA   BAA  FEDFUNDS  CPIAUCSL  CPIAUCNS  \
# 1854-12-01    NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 1855-01-01    NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 1855-02-01    NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 1855-03-01    NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 1855-04-01    NaN   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# ...           ...   ...   ...   ...   ...       ...       ...       ...
# 2023-06-01   5.16  3.75  5.24  4.65  5.75      5.08   303.841   305.109
# 2023-07-01   5.25  3.90  5.37  4.66  5.74      5.12   304.348   305.691
# 2023-08-01   5.30  4.17  5.37  4.95  6.02      5.33   306.269   307.026
# 2023-09-01   5.32  4.38  5.44  5.13  6.16      5.33   307.481   307.789
# 2023-10-01   5.34  4.80  5.42  5.61  6.63      5.33       NaN       NaN
#
#               INDPRO  UNRATE  USREC  RECPROUSM156N  CFNAI  UMCSENT  MICH  \
# 1854-12-01       NaN     NaN    1.0            NaN    NaN      NaN   NaN
# 1855-01-01       NaN     NaN    0.0            NaN    NaN      NaN   NaN
# 1855-02-01       NaN     NaN    0.0            NaN    NaN      NaN   NaN
# 1855-03-01       NaN     NaN    0.0            NaN    NaN      NaN   NaN
# 1855-04-01       NaN     NaN    0.0            NaN    NaN      NaN   NaN
# ...              ...     ...    ...            ...    ...      ...   ...
# 2023-06-01  102.2924     3.6    0.0           0.28  -0.40     64.2   3.3
# 2023-07-01  103.2895     3.5    0.0           0.06   0.20     71.5   3.4
# 2023-08-01  103.3170     3.8    0.0           0.02  -0.22     69.4   3.5
# 2023-09-01  103.6115     3.8    0.0           0.14   0.02     67.9   3.2
# 2023-10-01       NaN     NaN    NaN            NaN    NaN      NaN   NaN
#
#             USEPUINDXM  USEPUNEWSINDXM
# 1854-12-01         NaN             NaN
# 1855-01-01         NaN             NaN
# 1855-02-01         NaN             NaN
# 1855-03-01         NaN             NaN
# 1855-04-01         NaN             NaN
# ...                ...             ...
# 2023-06-01   145.02995       179.30804
# 2023-07-01   117.76544       132.71063
# 2023-08-01    88.46748        76.84670
# 2023-09-01   110.09229       113.80537
# 2023-10-01         NaN             NaN
#
# [2027 rows x 17 columns]

# %%
#| eval: false
rdat['D']
# Out:
#             DTB3  DGS10  DGS1  DAAA  DBAA   DFF  USEPUINDXD  VIXCLS  VXOCLS
# 1954-01-04  1.33    NaN   NaN   NaN   NaN   NaN         NaN     NaN     NaN
# 1954-01-05  1.28    NaN   NaN   NaN   NaN   NaN         NaN     NaN     NaN
# 1954-01-06  1.28    NaN   NaN   NaN   NaN   NaN         NaN     NaN     NaN
# 1954-01-07  1.31    NaN   NaN   NaN   NaN   NaN         NaN     NaN     NaN
# 1954-01-08  1.31    NaN   NaN   NaN   NaN   NaN         NaN     NaN     NaN
# ...          ...    ...   ...   ...   ...   ...         ...     ...     ...
# 2023-10-27  5.32   4.84  5.39  5.71  6.72  5.33       91.83   21.27     NaN
# 2023-10-28   NaN    NaN   NaN   NaN   NaN  5.33       59.81     NaN     NaN
# 2023-10-29   NaN    NaN   NaN   NaN   NaN  5.33       69.80     NaN     NaN
# 2023-10-30  5.33   4.88  5.41  5.73  6.74  5.33      176.55   19.75     NaN
# 2023-10-31  5.33   4.88  5.44  5.72  6.73  5.33       50.90   18.14     NaN
#
# [25449 rows x 9 columns]

# %%
#| export 
def clean(data: dict=None,        # If None, downloads `vars` using `download` function
          vars: List[str]=None,         # If None, downloads `default_raw_vars`
        labels: str=None, # Name you want to give to the series in the output DataFrame. If None, uses lowercase of `series`
        api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
        ) -> pd.DataFrame: 
    """Retrieves series from FRED, cleans the date and sets it as index"""

    if vars is None: vars = default_raw_vars()
    if data is None: data = download(vars, api_key=api_key)
    if labels is None: labels = pd.read_csv(LABELS_FILE).set_index('Variable Name')['Description'].to_dict()

    api = Fred(api_key=api_key)
    out = {}
    
    for freq, df in data.items():  
      df = df.rename(columns=labels).reset_index().rename({'index':'date'},axis=1)
      df = pdm.setup_tseries(df, freq=freq).drop('date', axis=1)
      out[freq] = df 

    return out

# %%
#| eval: false
cdat = clean(rdat)

# %%
#| eval: false
cdat.keys()
# Out:
# dict_keys(['M', 'D', 'Q'])

# %%
#| eval: false
cdat['Q']
# Out:
#            dtdate  indprod_q  nom_gdp  real_gdp  nom_gnp  real_gnp  pot_rgdp
# Qdate
# 1919Q1 1919-01-01     4.6783      NaN       NaN      NaN       NaN       NaN
# 1919Q2 1919-04-01     4.7141      NaN       NaN      NaN       NaN       NaN
# 1919Q3 1919-07-01     5.2339      NaN       NaN      NaN       NaN       NaN
# 1919Q4 1919-10-01     5.1085      NaN       NaN      NaN       NaN       NaN
# 1920Q1 1920-01-01     5.5835      NaN       NaN      NaN       NaN       NaN
# ...           ...        ...      ...       ...      ...       ...       ...
# 2024Q4 2024-10-01        NaN      NaN       NaN      NaN       NaN  21052.30
# 2025Q1 2025-01-01        NaN      NaN       NaN      NaN       NaN  21143.69
# 2025Q2 2025-04-01        NaN      NaN       NaN      NaN       NaN  21235.79
# 2025Q3 2025-07-01        NaN      NaN       NaN      NaN       NaN  21329.03
# 2025Q4 2025-10-01        NaN      NaN       NaN      NaN       NaN  21423.29
#
# [428 rows x 7 columns]

# %%
#| eval: false
cdat['M']
# Out:
#             dtdate  yield_3mt  yield_10yt  yield_1yt  yield_aaa  yield_baa  \
# Mdate
# 1854-12 1854-12-01        NaN         NaN        NaN        NaN        NaN
# 1855-01 1855-01-01        NaN         NaN        NaN        NaN        NaN
# 1855-02 1855-02-01        NaN         NaN        NaN        NaN        NaN
# 1855-03 1855-03-01        NaN         NaN        NaN        NaN        NaN
# 1855-04 1855-04-01        NaN         NaN        NaN        NaN        NaN
# ...            ...        ...         ...        ...        ...        ...
# 2023-06 2023-06-01       5.16        3.75       5.24       4.65       5.75
# 2023-07 2023-07-01       5.25        3.90       5.37       4.66       5.74
# 2023-08 2023-08-01       5.30        4.17       5.37       4.95       6.02
# 2023-09 2023-09-01       5.32        4.38       5.44       5.13       6.16
# 2023-10 2023-10-01       5.34        4.80       5.42       5.61       6.63
#
#          yield_fedf      cpi  cpi_nsa   indprod  unemp_rate  rec_dum  \
# Mdate
# 1854-12         NaN      NaN      NaN       NaN         NaN      1.0
# 1855-01         NaN      NaN      NaN       NaN         NaN      0.0
# 1855-02         NaN      NaN      NaN       NaN         NaN      0.0
# 1855-03         NaN      NaN      NaN       NaN         NaN      0.0
# 1855-04         NaN      NaN      NaN       NaN         NaN      0.0
# ...             ...      ...      ...       ...         ...      ...
# 2023-06        5.08  303.841  305.109  102.2924         3.6      0.0
# 2023-07        5.12  304.348  305.691  103.2895         3.5      0.0
# 2023-08        5.33  306.269  307.026  103.3170         3.8      0.0
# 2023-09        5.33  307.481  307.789  103.6115         3.8      0.0
# 2023-10        5.33      NaN      NaN       NaN         NaN      NaN
#
#          rec_prob  cfnai  sent_mich  exp_inflation     pu_bbd  punews_bbd
# Mdate
# 1854-12       NaN    NaN        NaN            NaN        NaN         NaN
# 1855-01       NaN    NaN        NaN            NaN        NaN         NaN
# 1855-02       NaN    NaN        NaN            NaN        NaN         NaN
# 1855-03       NaN    NaN        NaN            NaN        NaN         NaN
# 1855-04       NaN    NaN        NaN            NaN        NaN         NaN
# ...           ...    ...        ...            ...        ...         ...
# 2023-06      0.28  -0.40       64.2            3.3  145.02995   179.30804
# 2023-07      0.06   0.20       71.5            3.4  117.76544   132.71063
# 2023-08      0.02  -0.22       69.4            3.5   88.46748    76.84670
# 2023-09      0.14   0.02       67.9            3.2  110.09229   113.80537
# 2023-10       NaN    NaN        NaN            NaN        NaN         NaN
#
# [2027 rows x 18 columns]

# %%
#| eval: false
cdat['D']
# Out:
#                dtdate  yield_3mt  yield_10yt  yield_1yt  yield_aaa  yield_baa  \
# Ddate
# 1954-01-04 1954-01-04       1.33         NaN        NaN        NaN        NaN
# 1954-01-05 1954-01-05       1.28         NaN        NaN        NaN        NaN
# 1954-01-06 1954-01-06       1.28         NaN        NaN        NaN        NaN
# 1954-01-07 1954-01-07       1.31         NaN        NaN        NaN        NaN
# 1954-01-08 1954-01-08       1.31         NaN        NaN        NaN        NaN
# ...               ...        ...         ...        ...        ...        ...
# 2023-10-27 2023-10-27       5.32        4.84       5.39       5.71       6.72
# 2023-10-28 2023-10-28        NaN         NaN        NaN        NaN        NaN
# 2023-10-29 2023-10-29        NaN         NaN        NaN        NaN        NaN
# 2023-10-30 2023-10-30       5.33        4.88       5.41       5.73       6.74
# 2023-10-31 2023-10-31       5.33        4.88       5.44       5.72       6.73
#
#             yield_fedf  pu_bbd_d    vix  vxo
# Ddate
# 1954-01-04         NaN       NaN    NaN  NaN
# 1954-01-05         NaN       NaN    NaN  NaN
# 1954-01-06         NaN       NaN    NaN  NaN
# 1954-01-07         NaN       NaN    NaN  NaN
# 1954-01-08         NaN       NaN    NaN  NaN
# ...                ...       ...    ...  ...
# 2023-10-27        5.33     91.83  21.27  NaN
# 2023-10-28        5.33     59.81    NaN  NaN
# 2023-10-29        5.33     69.80    NaN  NaN
# 2023-10-30        5.33    176.55  19.75  NaN
# 2023-10-31        5.33     50.90  18.14  NaN
#
# [25449 rows x 10 columns]

# %%
#| export 
def search(search_text: str=None, # What to search for
              order_by: str='popularity', # How to order search results; try `search_rank` if you don't find what you were looking for
              nr_results: int=10, # How many results to output
              api_key: str=None # FRED api key. If None, will use os.getenv("FRED_API_KEY")
              ) -> pd.DataFrame:
    """Search FRED for a given `search_text`, sort by popularity and return only the first `nr_results`"""

    api = Fred(api_key=api_key)  
    return api.search(search_text, order_by=order_by)\
              .pipe(pdm.order_columns, ['title', 'popularity','frequency_short', 'observation_start', 'observation_end'])\
              .iloc[:nr_results].copy()

# %%
search("three month treasury bill", order_by='popularity',nr_results=3)
# Out:
#                                                        title popularity  \
# series id
# TB3MS      3-Month Treasury Bill Secondary Market Rate, D...         77
# DTB3       3-Month Treasury Bill Secondary Market Rate, D...         75
# DGS3MO     Market Yield on U.S. Treasury Securities at 3-...         73
#
#           frequency_short observation_start observation_end      id  \
# series id
# TB3MS                   M        1934-01-01      2023-10-01   TB3MS
# DTB3                    D        1954-01-04      2023-10-31    DTB3
# DGS3MO                  D        1981-09-01      2023-10-31  DGS3MO
#
#           realtime_start realtime_end frequency    units units_short  \
# series id
# TB3MS         2023-11-01   2023-11-01   Monthly  Percent           %
# DTB3          2023-11-01   2023-11-01     Daily  Percent           %
# DGS3MO        2023-11-01   2023-11-01     Daily  Percent           %
#
#                seasonal_adjustment seasonal_adjustment_short  \
# series id
# TB3MS      Not Seasonally Adjusted                       NSA
# DTB3       Not Seasonally Adjusted                       NSA
# DGS3MO     Not Seasonally Adjusted                       NSA
#
#                         last_updated  \
# series id
# TB3MS      2023-11-01 15:21:08-05:00
# DTB3       2023-11-01 15:20:09-05:00
# DGS3MO     2023-11-01 15:20:09-05:00
#
#                                                        notes
# series id
# TB3MS              Averages of Business Days, Discount Basis
# DTB3                                          Discount Basis
# DGS3MO     For further information regarding treasury con...

# %%
time.sleep(1)
search("three month treasury bill", order_by='search_rank',nr_results=3)
# Out:
#                                                        title popularity  \
# series id
# TB3MS      3-Month Treasury Bill Secondary Market Rate, D...         77
# DTB3       3-Month Treasury Bill Secondary Market Rate, D...         75
# WTB3MS     3-Month Treasury Bill Secondary Market Rate, D...         45
#
#           frequency_short observation_start observation_end      id  \
# series id
# TB3MS                   M        1934-01-01      2023-10-01   TB3MS
# DTB3                    D        1954-01-04      2023-10-31    DTB3
# WTB3MS                  W        1954-01-08      2023-10-27  WTB3MS
#
#           realtime_start realtime_end              frequency    units  \
# series id
# TB3MS         2023-11-01   2023-11-01                Monthly  Percent
# DTB3          2023-11-01   2023-11-01                  Daily  Percent
# WTB3MS        2023-11-01   2023-11-01  Weekly, Ending Friday  Percent
#
#           units_short      seasonal_adjustment seasonal_adjustment_short  \
# series id
# TB3MS               %  Not Seasonally Adjusted                       NSA
# DTB3                %  Not Seasonally Adjusted                       NSA
# WTB3MS              %  Not Seasonally Adjusted                       NSA
#
#                         last_updated  \
# series id
# TB3MS      2023-11-01 15:21:08-05:00
# DTB3       2023-11-01 15:20:09-05:00
# WTB3MS     2023-10-30 15:27:01-05:00
#
#                                                notes
# series id
# TB3MS      Averages of Business Days, Discount Basis
# DTB3                                  Discount Basis
# WTB3MS     Averages of Business Days, Discount Basis

# %%
#| hide
import nbdev; nbdev.nbdev_export()
