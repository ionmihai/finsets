# %% [markdown]
# # ibes_ltg
#
# > Retrieve and process data on EPS Long-Term Growth (LTG) forecasts from WRDS IBES database.

# %% [markdown]
# ***
#
# The Forecast Period End Date (`fpedats`) is the ending month and year of the fiscal period to which the estimate applies (unless you're asking for a long-term-growth estimate, in which case the horizon is 3-5 years, so no explicity fiscal period is applicable).
#
# The Activation Date (`actdats`) is the date that the forecast/actual was recorded by Thomson Reuters.
#
# The Announce Date (`anndats`) is the date that the forecast/actual was reported.
#
# The Review Date (`revdats`) is most recent date that an estimate was confirmed as accurate.
#
# The Forecast Period Indicator (`fpi`) contains information about the horizon (how far into the future we are estimating). Key values: '0' for LTG, '1'-'5' for 1 to 5 years in the future, '6'-'9' for 1 to 4 quarters in the future. Farther horizons are available but they are extremely poorly populated.
#
# Note that for Long Term Growth (LTG) estimates (`fpi='0'`), you must NOT select "Forecast Period End Date" as the Date Variable or the query will not return any estimates.
#
# `TICKER` is the IBES ticker, which is not necessarily the same as the offical ticker of the firm.
#
# ***
# It is possible for a contributing broker to provide multiple revisions to an estimate on the same day. In
# this scenario, all estimates are available in the Detail history files and only the most current estimate is
# included in the mean.
#
# The Brokers (`estimator`) and Analysts (`analys`) are provided under numeric codes.
#
# ***
# **Estimate Revisions**
#
# There are estimates which are dated “after” the announcement date. We
# have no explanation other than the entry is in error.
#
# Announcement of earnings will increment the FPI variable by 1 in all IBES
# records for which review date (REVDATS)> report date (ANNDATS_ACT)
#
# If at the time of the next review date the analyst at the same brokerage changes
# her forecast for the same (TICKER, ANNDATS, FPEDATS, FPI, MEASURE,
# USFIRM) combination, IBES will add a new observation. If the forecast
# remains unchanged, IBES will not add new observations, but will adjust the
# review date accordingly (REVDATS)
#
# ***

# %%
#| default_exp wrds.ibes_ltg

# %%
#|exports
from __future__ import annotations
from pathlib import Path
from typing import List
import os

import pandas as pd
import numpy as np

import pandasmore as pdm
from finsets.wrds import wrds_api
from finsets import RESOURCES

# %%
#| exports
PROVIDER = 'Refinitiv via WRDS'
URL = 'https://wrds-www.wharton.upenn.edu/pages/get-data/ibes-thomson-reuters/ibes-academic/unadjusted-detail/history/'
LIBRARY = 'ibes'
TABLE = 'detu_epsus'
LINK_LIBRARY = 'wrdsapps_link_crsp_ibes'
LINK_TABLE = 'ibcrsphist'
FREQ = 'M'
MIN_YEAR = 1925
MAX_YEAR = None
ENTITY_ID_IN_RAW_DSET = 'permno'
ENTITY_ID_IN_CLEAN_DSET = 'permno'
TIME_VAR_IN_RAW_DSET = 'date'
TIME_VAR_IN_CLEAN_DSET = 'Mdate'

# %%
#| export 
def raw_metadata(rawfile: str|Path=RESOURCES/'ibes_detu_epsus_variable_descriptions.csv', # location of the raw variable labels file
             ) -> pd.DataFrame:
    "Loads raw variable labels file, cleans it and returns it as a pd.DataFrame"

    df = pd.read_csv(rawfile)
    df['output_of'] = 'wrds.ibes_ltg.clean'

    df['Variable Label'] = df.apply(lambda row: row['Description'].replace(row['Variable Name'].strip()+' -- ', ''), axis=1)
    df['Variable Label'] = df.apply(lambda row: row['Variable Label'].replace( '(' + row['Variable Name'].strip() + ')', ''), axis=1)
    df['Variable Name'] = df['Variable Name'].str.strip().str.lower()
    df = df[['Variable Name', 'Variable Label', 'output_of', 'Type']].copy()
    df.columns = ['name','label','output_of','type']
    return df

# %%
raw_metadata()
# Out:
#            name                                              label  \
# 0         oftic                                   Official Ticker
# 1        ticker                                    I/B/E/S Ticker
# 2         cusip                                       CUSIP/SEDOL
# 3         cname                                      Company Name
# 4       fpedats              Forecast Period End Date, SAS Format
# 5       actdats                       Activation Date, SAS Format
# 6       acttims                       Activation Time, SAS Format
# 7       revdats                           Review Date, SAS Format
# 8       revtims                           Review Time, SAS Format
# 9       anndats                         Announce Date, SAS Format
# 10      anntims                         Announce Time, SAS Format
# 11    estimator                                         Estimator
# 12       analys                                      Analyst Code
# 13        value                                    Estimate Value
# 14       usfirm  U.S. Firm (USFIRM=0 if from .INT and USFIRM=1 ...
# 15       currfl            Canadian Currency Flag(Estimate Level)
# 16         curr                                          Currency
# 17  report_curr         Report Currency from Report Currency File
# 18          pdf              Primary/Diluted Flag(Estimate Level)
#
#               output_of   type
# 0   wrds.ibes_ltg.clean   Char
# 1   wrds.ibes_ltg.clean   Char
# 2   wrds.ibes_ltg.clean   Char
# 3   wrds.ibes_ltg.clean   Char
# 4   wrds.ibes_ltg.clean  Float
# 5   wrds.ibes_ltg.clean   Date
# 6   wrds.ibes_ltg.clean  Float
# 7   wrds.ibes_ltg.clean  Float
# 8   wrds.ibes_ltg.clean  Float
# 9   wrds.ibes_ltg.clean   Date
# 10  wrds.ibes_ltg.clean  Float
# 11  wrds.ibes_ltg.clean  Float
# 12  wrds.ibes_ltg.clean  Float
# 13  wrds.ibes_ltg.clean  Float
# 14  wrds.ibes_ltg.clean  Float
# 15  wrds.ibes_ltg.clean   Char
# 16  wrds.ibes_ltg.clean   Char
# 17  wrds.ibes_ltg.clean   Char
# 18  wrds.ibes_ltg.clean   Char

# %%
#| export
def raw_metadata_extra(wrds_username: str=None
             ) -> pd.DataFrame:
    "Collects metadata from WRDS `{LIBRARY}.{TABLE}` table and merges it with `raw_metadata()`."

    if wrds_username is None:
        wrds_username = os.getenv('WRDS_USERNAME')
        if wrds_username is None: wrds_username = input("Enter your WRDS username: ") 

    try:
        db = wrds_api.Connection(wrds_username = wrds_username)
        funda = db.describe_table(LIBRARY,TABLE)
        nr_rows = db.get_row_count(LIBRARY,TABLE)
    finally:
        db.close()

    meta = funda[['name','type']].copy()
    meta['nr_rows'] = nr_rows
    meta['wrds_library'] = LIBRARY
    meta['wrds_table'] = TABLE

    meta = meta.merge(raw_metadata()[['name','label']], how='left', on='name')
    
    meta['output_of'] = 'wrds.ibes_ltg.download'
    meta = pdm.order_columns(meta,these_first=['name','label','output_of'])
    for v in list(meta.columns):
        meta[v] = meta[v].astype('string')
    
    return meta

# %%
#| eval: false
raw_metadata_extra()
# Out:
# Loading library list...
# Done
# Approximately 31823580 rows in ibes.detu_epsus.
#            name                                              label  \
# 0        ticker                                    I/B/E/S Ticker
# 1         cusip                                       CUSIP/SEDOL
# 2         oftic                                   Official Ticker
# 3         cname                                      Company Name
# 4       actdats                       Activation Date, SAS Format
# 5     estimator                                         Estimator
# 6        analys                                      Analyst Code
# 7        currfl            Canadian Currency Flag(Estimate Level)
# 8           pdf              Primary/Diluted Flag(Estimate Level)
# 9           fpi                                               <NA>
# 10      measure                                               <NA>
# 11        value                                    Estimate Value
# 12         curr                                          Currency
# 13       usfirm  U.S. Firm (USFIRM=0 if from .INT and USFIRM=1 ...
# 14      fpedats              Forecast Period End Date, SAS Format
# 15      acttims                       Activation Time, SAS Format
# 16      revdats                           Review Date, SAS Format
# 17      revtims                           Review Time, SAS Format
# 18      anndats                         Announce Date, SAS Format
# 19      anntims                         Announce Time, SAS Format
# 20  report_curr         Report Currency from Report Currency File
#
#                  output_of              type   nr_rows wrds_library  \
# 0   wrds.ibes_ltg.download        VARCHAR(6)  31823580         ibes
# 1   wrds.ibes_ltg.download        VARCHAR(8)  31823580         ibes
# 2   wrds.ibes_ltg.download        VARCHAR(6)  31823580         ibes
# 3   wrds.ibes_ltg.download       VARCHAR(16)  31823580         ibes
# 4   wrds.ibes_ltg.download              DATE  31823580         ibes
# 5   wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 6   wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 7   wrds.ibes_ltg.download        VARCHAR(1)  31823580         ibes
# 8   wrds.ibes_ltg.download        VARCHAR(1)  31823580         ibes
# 9   wrds.ibes_ltg.download        VARCHAR(1)  31823580         ibes
# 10  wrds.ibes_ltg.download        VARCHAR(3)  31823580         ibes
# 11  wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 12  wrds.ibes_ltg.download        VARCHAR(3)  31823580         ibes
# 13  wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 14  wrds.ibes_ltg.download              DATE  31823580         ibes
# 15  wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 16  wrds.ibes_ltg.download              DATE  31823580         ibes
# 17  wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 18  wrds.ibes_ltg.download              DATE  31823580         ibes
# 19  wrds.ibes_ltg.download  DOUBLE_PRECISION  31823580         ibes
# 20  wrds.ibes_ltg.download        VARCHAR(3)  31823580         ibes
#
#     wrds_table
# 0   detu_epsus
# 1   detu_epsus
# 2   detu_epsus
# 3   detu_epsus
# 4   detu_epsus
# 5   detu_epsus
# 6   detu_epsus
# 7   detu_epsus
# 8   detu_epsus
# 9   detu_epsus
# 10  detu_epsus
# 11  detu_epsus
# 12  detu_epsus
# 13  detu_epsus
# 14  detu_epsus
# 15  detu_epsus
# 16  detu_epsus
# 17  detu_epsus
# 18  detu_epsus
# 19  detu_epsus
# 20  detu_epsus

# %%
#| export 
def default_raw_vars():
    return ['ticker', 'value', 'fpi', 'anndats', 'fpedats', 'revdats', 'actdats', 'estimator', 'analys', 'pdf']

# %%
#| export
def parse_varlist(vars: List[str]=None, #list of variables requested by user
                  req_vars: List[str] = ['ticker', 'anndats'], #list of variables that will automatically get downloaded, even if not in `vars`
                  prefix: str='a.', #string to add in front of each variable name when we build the SQL string of variable names
                  ) -> str:
    """Add required variables to requested variables, validate them, and build the sql string with their names"""

    # Build full list of variables that will be downloaded
    if vars is None: vars = default_raw_vars()
    if req_vars is None: req_vars = []
    vars =  req_vars + [x for x in vars if x not in req_vars] #in case `vars` already contains some of the required variables

    # Validate variables to be downloaded (make sure that they are in the target database)
    valid_vars = list(raw_metadata_extra().name)
    invalid_vars = [v for v in vars if v not in valid_vars]
    if invalid_vars: raise ValueError(f"These vars are not in the database: {invalid_vars}") 

    return ','.join([f'{prefix}{var_name}' for var_name in vars])

# %%
#| export
def download(vars: List[str]=None, # If None, downloads `default_raw_vars`; `permno`, `ticker`, and `anndats` added by default
             obs_limit: int=None, #Number of rows to download. If None, full dataset will be downloaded
             wrds_username: str=None, #If None, looks for WRDS_USERNAME with `os.getenv`, then prompts you if needed
             start_date: str=None, # Start date in MM/DD/YYYY format
             end_date: str=None, #End date in MM/DD/YYYY format; if None, defaults to current date
             permno_match_score: tuple=(1,), #accuracy of permno-ibes link. 1-6. 1 is best. use >1 with caution.
             ) -> pd.DataFrame:
    """Downloads `vars` from `start_date` to `end_date` from WRDS `ibes.detu_epsus` library and adds PERMNO from CRSP"""

    vars = parse_varlist(vars)

    sql_string=f"""SELECT {vars}, b.permno
                        FROM {LIBRARY}.{TABLE} AS a
                        LEFT JOIN {LINK_LIBRARY}.{LINK_TABLE} AS b
                        ON a.ticker = b.ticker
                        WHERE a.anndats BETWEEN b.sdate AND b.edate
                                AND fpi='0'
                """
    if permno_match_score is not None: sql_string += r" AND score IN %(permno_match_score)s"
    if start_date is not None: sql_string += r" AND anndats >= %(start_date)s"
    if end_date is not None: sql_string += r" AND anndats <= %(end_date)s"
    if obs_limit is not None: sql_string += r" LIMIT %(obs_limit)s"

    return wrds_api.download(sql_string, wrds_username=wrds_username, 
                             params={'permno_match_score': permno_match_score,
                                 'start_date':start_date, 'end_date':end_date, 'obs_limit':obs_limit})

# %%
#| eval: false
ltg = download(permno_match_score=(1,2), start_date='01/01/2019', end_date='01/01/2022', obs_limit=1000)
ltg
# Out:
# Loading library list...
# Done
# Approximately 31823580 rows in ibes.detu_epsus.
# Loading library list...
# Done
#     ticker     anndats  value fpi fpedats     revdats     actdats  estimator  \
# 0     0001  2019-01-04 -174.4   0    None  2019-01-04  2019-01-04      183.0
# 1     0001  2019-01-24 -173.7   0    None  2019-01-24  2019-01-24      183.0
# 2     0001  2019-03-17 -174.4   0    None  2019-03-17  2019-03-17      183.0
# 3     000R  2019-08-15   15.0   0    None  2019-12-20  2019-08-15      481.0
# 4     000Y  2019-09-18  -84.4   0    None  2019-09-24  2019-09-24      183.0
# ..     ...         ...    ...  ..     ...         ...         ...        ...
# 995   00UX  2019-12-17   -2.7   0    None  2020-01-20  2019-12-17      183.0
# 996   00UX  2020-02-11    7.5   0    None  2020-02-12  2020-02-12      183.0
# 997   00UX  2020-02-21    7.1   0    None  2020-03-16  2020-02-21      183.0
# 998   00UX  2020-03-25    5.4   0    None  2020-03-25  2020-03-25      183.0
# 999   00UX  2020-03-27   14.3   0    None  2020-03-27  2020-03-27     3037.0
#
#        analys pdf   permno
# 0     48368.0   D  14392.0
# 1     48368.0   D  14392.0
# 2     48368.0   D  14392.0
# 3    114029.0   D  14378.0
# 4    162718.0   D  14436.0
# ..        ...  ..      ...
# 995  107332.0   D  15647.0
# 996  107332.0   D  15647.0
# 997  107332.0   D  15647.0
# 998  107332.0   D  15647.0
# 999  136937.0   D  15647.0
#
# [1000 rows x 11 columns]

# %%
#| hide
import nbdev; nbdev.nbdev_export()
