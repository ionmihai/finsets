# %% [markdown]
# # core

# %% [markdown]
# > Functions that are not specific to individual data sources

# %% [markdown]
# These functions are available directly from the finsets namespace. For example to use the `features_metadata` function below, use
#
# ```python
# from finsets import features_metadata
# ```

# %%
#| default_exp core

# %%
#| export
from __future__ import annotations
from typing import Literal
from importlib import import_module
from inspect import signature

import pandas as pd
from  thefuzz import process, fuzz

from fastcore.script import call_parse

from finsets import RESOURCES

# %%
#| exports 
METADATA_FILE = RESOURCES/'all_metadata.pkl'

# %%
#| export
def features_metadata(submodules: list=['wrds', 'papers'] # list of submodules to collect metadata from
                      ) -> pd.DataFrame:
    "Go through `submodules` of `finsets` and collect metadata from all functions that have `return_metadata` parameter"
    
    df = pd.DataFrame(columns=['name','label','output_of','inputs','inputs_generated_by'])
    for name in submodules:
        module = import_module(f'finsets.{name}')
        for sub in dir(module):
            if sub.startswith('_'): continue
            submodule = import_module(f'finsets.{name}.{sub}')
            for func_name in submodule.__all__:
                func = getattr(submodule, func_name)
                if callable(func):
                    try: 
                        params = signature(func).parameters
                    except:
                        continue
                    if 'return_metadata' in params: 
                        meta = func(return_metadata=True)
                        for var_name in meta['outputs']:
                            for input_name in meta['inputs']:    
                                new_meta = pd.DataFrame({'name':var_name, 
                                                'label':meta['labels'][var_name], 
                                                'output_of':f'{name}.{sub}.{func_name}', 
                                                'inputs':','.join(meta['inputs'][input_name]),
                                                'inputs_generated_by':input_name}, index=[0])
                                df = pd.concat([df,new_meta],ignore_index=True)
    return df

# %%
features_metadata()
# Out:
#              name                         label  \
# 0          bookeq                   Book equity
# 1           shreq            Shareholder equity
# 2      pref_stock               Preferred stock
# 3          tobinq                       Tobin Q
# 4   equityiss_tot               Equity issuance
# 5   equityiss_cfs               Equity issuance
# 6     debtiss_tot                 Debt issuance
# 7     debtiss_cfs                 Debt issuance
# 8      debtiss_bs                 Debt issuance
# 9        ppentpch         Pct change in net PPE
# 10        capx2la         CAPX to lagged assets
# 11            roa              Return on assets
# 12    cflow2la_is   Cash flows to lagged assets
# 13   cflow2la_cfs   Cash flows to lagged assets
# 14  cflow2la_full   Cash flows to lagged assets
# 15         cash2a       Cash holdings to assets
# 16        booklev                 Book leverage
# 17         div2la    Dividends to lagged assets
# 18         rep2la  Repurchases to lagged assets
#
#                         output_of  \
# 0          wrds.compa.book_equity
# 1          wrds.compa.book_equity
# 2          wrds.compa.book_equity
# 3              wrds.compa.tobin_q
# 4        wrds.compa.issuance_vars
# 5        wrds.compa.issuance_vars
# 6        wrds.compa.issuance_vars
# 7        wrds.compa.issuance_vars
# 8        wrds.compa.issuance_vars
# 9      wrds.compa.investment_vars
# 10     wrds.compa.investment_vars
# 11  wrds.compa.profitability_vars
# 12       wrds.compa.cashflow_vars
# 13       wrds.compa.cashflow_vars
# 14       wrds.compa.cashflow_vars
# 15      wrds.compa.liquidity_vars
# 16       wrds.compa.leverage_vars
# 17         wrds.compa.payout_vars
# 18         wrds.compa.payout_vars
#
#                                                inputs inputs_generated_by
# 0         at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb    wrds.compa.clean
# 1         at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb    wrds.compa.clean
# 2         at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb    wrds.compa.clean
# 3   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,pr...    wrds.compa.clean
# 4   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,ss...    wrds.compa.clean
# 5   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,ss...    wrds.compa.clean
# 6   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,ss...    wrds.compa.clean
# 7   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,ss...    wrds.compa.clean
# 8   at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,ss...    wrds.compa.clean
# 9                                       ppent,capx,at    wrds.compa.clean
# 10                                      ppent,capx,at    wrds.compa.clean
# 11                                              ib,at    wrds.compa.clean
# 12                              dtdate,oancf,ib,dp,at    wrds.compa.clean
# 13                              dtdate,oancf,ib,dp,at    wrds.compa.clean
# 14                              dtdate,oancf,ib,dp,at    wrds.compa.clean
# 15                                             che,at    wrds.compa.clean
# 16                                        dltt,dlc,at    wrds.compa.clean
# 17                                      dvc,prstkc,at    wrds.compa.clean
# 18                                      dvc,prstkc,at    wrds.compa.clean

# %%
#| export
def raw_metadata(submodules=['wrds', 'papers'] # list of submodules to collect metadata from
                ) -> pd.DataFrame:
    "Go through `submodules` of `finsets` and collect metadata from `raw_metadata` functions (if present)"

    df = pd.DataFrame(columns=['name','label','output_of','type'])
    for name in submodules:
        module = import_module(f'finsets.{name}')
        for sub in dir(module):
            if sub.startswith('_'): continue
            submodule = import_module(f'finsets.{name}.{sub}')
            if 'raw_metadata' in submodule.__all__:
                df = pd.concat([df,submodule.raw_metadata()],ignore_index=True)
    return df

# %%
raw_metadata()
# Out:
# Loading library list...
# Done
# Approximately 881742 rows in comp.funda.
# Loading library list...
# Done
# Approximately 4922867 rows in crsp.msf.
# Approximately 111623 rows in crsp.msenames.
# Loading library list...
# Done
# Approximately 2750800 rows in wrdsapps_finratio_ibes.firm_ratio_ibes.
#             name                                 label             output_of  \
# 0          gvkey                   Global Company Key    wrds.compa.download
# 1       datadate                                  <NA>   wrds.compa.download
# 2          fyear                   Data Year - Fiscal    wrds.compa.download
# 3         indfmt                                  <NA>   wrds.compa.download
# 4         consol                                  <NA>   wrds.compa.download
# ...          ...                                   ...                   ...
# 1085       ffi48                                  <NA>  wrds.ratios.download
# 1086  ffi49_desc                                  <NA>  wrds.ratios.download
# 1087       ffi49                                  <NA>  wrds.ratios.download
# 1088      ticker  EXCHANGE TICKER SYMBOL - HISTORICAL   wrds.ratios.download
# 1089       cusip        CUSIP IDENTIFIER - HISTORICAL   wrds.ratios.download
#
#                   type  nr_rows LIBRARY  TABLE            wrds_library  \
# 0           VARCHAR(6)   881742    comp  funda                    <NA>
# 1                 DATE   881742    comp  funda                    <NA>
# 2     DOUBLE_PRECISION   881742    comp  funda                    <NA>
# 3          VARCHAR(12)   881742    comp  funda                    <NA>
# 4           VARCHAR(2)   881742    comp  funda                    <NA>
# ...                ...      ...     ...    ...                     ...
# 1085  DOUBLE_PRECISION  2750800    <NA>   <NA>  wrdsapps_finratio_ibes
# 1086        VARCHAR(5)  2750800    <NA>   <NA>  wrdsapps_finratio_ibes
# 1087  DOUBLE_PRECISION  2750800    <NA>   <NA>  wrdsapps_finratio_ibes
# 1088        VARCHAR(8)  2750800    <NA>   <NA>  wrdsapps_finratio_ibes
# 1089        VARCHAR(8)  2750800    <NA>   <NA>  wrdsapps_finratio_ibes
#
#            wrds_table group
# 0                <NA>  <NA>
# 1                <NA>  <NA>
# 2                <NA>  <NA>
# 3                <NA>  <NA>
# 4                <NA>  <NA>
# ...               ...   ...
# 1085  firm_ratio_ibes  <NA>
# 1086  firm_ratio_ibes  <NA>
# 1087  firm_ratio_ibes  <NA>
# 1088  firm_ratio_ibes    ID
# 1089  firm_ratio_ibes    ID
#
# [1090 rows x 10 columns]

# %%
#| export
def all_metadata(submodules=['wrds', 'papers'] # list of submodules to collect metadata from
                ) -> pd.DataFrame:
    "Collects `raw_metadata` and `features_metadata` from `submodules` of `finsets`"

    df =  pd.concat([features_metadata(submodules), raw_metadata(submodules)], ignore_index=True)
    df.to_pickle(METADATA_FILE)
    return df

# %%
meta = all_metadata()
# Out:
# Loading library list...
# Done
# Approximately 881742 rows in comp.funda.
# Loading library list...
# Done
# Approximately 4922867 rows in crsp.msf.
# Approximately 111623 rows in crsp.msenames.
# Loading library list...
# Done
# Approximately 2750800 rows in wrdsapps_finratio_ibes.firm_ratio_ibes.

# %%
#| export
@call_parse
def search(query: str,              # What to search for 
           meta: str='all',   #"all", "features", or "raw"; specifies the function that fetches the metadata you want to search through
           field: str='label', # Which column in the metadata table you want to search through. Use "name" to search variable names.  
           limit: int=10,           # How many results to display                      
           ) -> pd.DataFrame:
    "Search for `query` in metadata returned by f`{meta_func}_metadata`; return `limit` number of results"

    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 100)

    try:   
        #import finsets
        metadata = pd.read_pickle(METADATA_FILE)  #getattr(finsets, f'{meta}_metadata')()
        results = process.extractBests(query, metadata[field].dropna().astype('string'), 
                                        scorer = fuzz.token_sort_ratio,
                                        limit=limit)
        rows = [x[2] for x in results]
        scores = [x[1] for x in results]
        df = metadata.iloc[rows]
        df.index = scores
        df.index.name="SCORE"
        df.columns = df.columns.str.upper()
    finally:
        pd.reset_option('display.max_columns')
        pd.reset_option('display.width')        
    return df

# %%
meta.label.astype('string')
# Out:
# 0                                Book equity
# 1                         Shareholder equity
# 2                            Preferred stock
# 3                                    Tobin Q
# 4                            Equity issuance
#                         ...
# 1104                                    <NA>
# 1105                                    <NA>
# 1106                                    <NA>
# 1107    EXCHANGE TICKER SYMBOL - HISTORICAL
# 1108          CUSIP IDENTIFIER - HISTORICAL
# Name: label, Length: 1109, dtype: string

# %%
search('tobins q')
# Out:
#            NAME                      LABEL            OUTPUT_OF  \
# SCORE
# 93       tobinq                    Tobin Q   wrds.compa.tobin_q
# 50          aqc              Acquisitions   wrds.compa.download
# 45     acqlntal            Acquired Loans   wrds.compa.download
# 43        optgr         Options - Granted   wrds.compa.download
# 43         pvon  Provisions - Other (Net)   wrds.compa.download
# 42          bid               Closing Bid   wrds.crspm.download
# 42          ask               Closing Ask   wrds.crspm.download
# 40        optca   Options - Cancelled (-)   wrds.compa.download
# 40       optexd   Options - Exercised (-)   wrds.compa.download
# 40          wdp         Writedowns Pretax   wrds.compa.download
#
#                                                   INPUTS INPUTS_GENERATED_BY  \
# SCORE
# 93     at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,pr...    wrds.compa.clean
# 50                                                   NaN                 NaN
# 45                                                   NaN                 NaN
# 43                                                   NaN                 NaN
# 43                                                   NaN                 NaN
# 42                                                   NaN                 NaN
# 42                                                   NaN                 NaN
# 40                                                   NaN                 NaN
# 40                                                   NaN                 NaN
# 40                                                   NaN                 NaN
#
#                    TYPE  NR_ROWS LIBRARY  TABLE WRDS_LIBRARY WRDS_TABLE GROUP
# SCORE
# 93                 <NA>     <NA>    <NA>   <NA>         <NA>       <NA>  <NA>
# 50     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 45     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 43     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 43     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 42     DOUBLE_PRECISION  4922867    <NA>   <NA>         crsp        msf  <NA>
# 42     DOUBLE_PRECISION  4922867    <NA>   <NA>         crsp        msf  <NA>
# 40     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 40     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>
# 40     DOUBLE_PRECISION   881742    comp  funda         <NA>       <NA>  <NA>

# %%
search('total assets', meta = 'raw', limit=5)
# Out:
#        NAME                      LABEL         OUTPUT_OF    TYPE
# SCORE
# 100      at            Assets - Total   wrds.compa.clean  double
# 75      act    Current Assets - Total   wrds.compa.clean  double
# 75       ao            Assets - Other   wrds.compa.clean  double
# 71     batr  Benefits Assumed - Total   wrds.compa.clean  double
# 69     dptb  Deposits - Total - Banks   wrds.compa.clean  double

# %%
search('cash flows', meta = 'features')
# Out:
#                 NAME                         LABEL  \
# SCORE
# 54       cflow2la_is   Cash flows to lagged assets
# 54      cflow2la_cfs   Cash flows to lagged assets
# 54     cflow2la_full   Cash flows to lagged assets
# 42            cash2a       Cash holdings to assets
# 32           capx2la         CAPX to lagged assets
# 31               roa              Return on assets
# 28            div2la    Dividends to lagged assets
# 26            rep2la  Repurchases to lagged assets
# 24            tobinq                       Tobin Q
# 21             shreq            Shareholder equity
#
#                            OUTPUT_OF  \
# SCORE
# 54          wrds.compa.cashflow_vars
# 54          wrds.compa.cashflow_vars
# 54          wrds.compa.cashflow_vars
# 42         wrds.compa.liquidity_vars
# 32        wrds.compa.investment_vars
# 31     wrds.compa.profitability_vars
# 28            wrds.compa.payout_vars
# 26            wrds.compa.payout_vars
# 24                wrds.compa.tobin_q
# 21            wrds.compa.book_equity
#
#                                                   INPUTS INPUTS_GENERATED_BY
# SCORE
# 54                                 dtdate,oancf,ib,dp,at    wrds.compa.clean
# 54                                 dtdate,oancf,ib,dp,at    wrds.compa.clean
# 54                                 dtdate,oancf,ib,dp,at    wrds.compa.clean
# 42                                                che,at    wrds.compa.clean
# 32                                         ppent,capx,at    wrds.compa.clean
# 31                                                 ib,at    wrds.compa.clean
# 28                                         dvc,prstkc,at    wrds.compa.clean
# 26                                         dvc,prstkc,at    wrds.compa.clean
# 24     at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb,pr...    wrds.compa.clean
# 21           at,lt,seq,ceq,txditc,pstk,pstkrv,pstkl,itcb    wrds.compa.clean

# %%
search('txditc', field='name', limit=5)
# Out:
#          NAME                                      LABEL         OUTPUT_OF  \
# SCORE
# 100    txditc  Deferred Taxes and Investment Tax Credit   wrds.compa.clean
# 80       txdi                   Income Taxes - Deferred   wrds.compa.clean
# 80       txdc                Deferred Taxes (Cash Flow)   wrds.compa.clean
# 67        tic                             Ticker Symbol   wrds.compa.clean
# 67     txdbca              Deferred Tax Asset - Current   wrds.compa.clean
#
#       INPUTS INPUTS_GENERATED_BY    TYPE
# SCORE
# 100      NaN                 NaN  double
# 80       NaN                 NaN  double
# 80       NaN                 NaN  double
# 67       NaN                 NaN  string
# 67       NaN                 NaN  double

# %%
#| hide
import nbdev; nbdev.nbdev_export()
